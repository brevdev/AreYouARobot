# %% [markdown]
# ## Rules

# %% [markdown]
# ![AYAR Rules1.png](attachment:4f14b095-c766-4651-b9a1-222ff7c74dbf.png)

# %%
from enum import Enum
from random import choice, choices


class Card(Enum):
    Human = 0
    Robot = 1 



class Choices(Enum):
    Zap = 0
    Shake = 1


class Outcome(Enum):
    BothLose = 0
    BothWin = 1
    HumanWin = 2
    RobotWin = 3
    Stalemate = 4


def strategy_random_choice(player, hist):
    if not player.is_human: return Choices.Shake
    return choice([Choices.Zap, Choices.Shake])


def strategy_always_shake(player, hist):
    return Choices.Shake


def strategy_always_zap(player, hist):
    if not player.is_human: return Choices.Shake
    return Choices.Zap


def strategy_random_choice_1_to_99(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.1,0.99],
        k=1
    )[0]


def strategy_random_choice_2_to_98(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.2,0.98],
        k=1
    )[0]


def strategy_random_choice_3_to_97(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.3,0.97],
        k=1
    )[0]


def strategy_random_choice_4_to_96(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.4,0.96],
        k=1
    )[0]


def strategy_random_choice_5_to_95(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.5,0.95],
        k=1
    )[0]


def strategy_random_choice_6_to_94(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.6,0.94],
        k=1
    )[0]


def strategy_random_choice_7_to_93(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.7,0.93],
        k=1
    )[0]


def strategy_random_choice_8_to_92(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.8,0.92],
        k=1
    )[0]


def strategy_random_choice_9_to_91(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.9,0.91],
        k=1
    )[0]


def strategy_random_choice_10_to_90(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.10,0.90],
        k=1
    )[0]


def strategy_random_choice_11_to_89(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.11,0.89],
        k=1
    )[0]


def strategy_random_choice_12_to_88(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.12,0.88],
        k=1
    )[0]


def strategy_random_choice_13_to_87(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.13,0.87],
        k=1
    )[0]


def strategy_random_choice_14_to_86(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.14,0.86],
        k=1
    )[0]


def strategy_random_choice_15_to_85(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.15,0.85],
        k=1
    )[0]


def strategy_random_choice_16_to_84(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.16,0.84],
        k=1
    )[0]


def strategy_random_choice_17_to_83(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.17,0.83],
        k=1
    )[0]


def strategy_random_choice_18_to_82(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.18,0.82],
        k=1
    )[0]


def strategy_random_choice_19_to_81(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.19,0.81],
        k=1
    )[0]


def strategy_random_choice_20_to_80(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.20,0.80],
        k=1
    )[0]


def strategy_random_choice_21_to_79(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.21,0.79],
        k=1
    )[0]


def strategy_random_choice_22_to_78(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.22,0.78],
        k=1
    )[0]


def strategy_random_choice_23_to_77(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.23,0.77],
        k=1
    )[0]


def strategy_random_choice_24_to_76(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.24,0.76],
        k=1
    )[0]


def strategy_random_choice_25_to_75(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.25,0.75],
        k=1
    )[0]


def strategy_random_choice_26_to_74(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.26,0.74],
        k=1
    )[0]


def strategy_random_choice_27_to_73(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.27,0.73],
        k=1
    )[0]


def strategy_random_choice_28_to_72(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.28,0.72],
        k=1
    )[0]


def strategy_random_choice_29_to_71(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.29,0.71],
        k=1
    )[0]


def strategy_random_choice_30_to_70(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.30,0.70],
        k=1
    )[0]


def strategy_random_choice_31_to_69(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.31,0.69],
        k=1
    )[0]


def strategy_random_choice_32_to_68(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.32,0.68],
        k=1
    )[0]


def strategy_random_choice_33_to_67(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.33,0.67],
        k=1
    )[0]


def strategy_random_choice_34_to_66(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.34,0.66],
        k=1
    )[0]


def strategy_random_choice_35_to_65(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.35,0.65],
        k=1
    )[0]


def strategy_random_choice_36_to_64(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.36,0.64],
        k=1
    )[0]


def strategy_random_choice_37_to_63(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.37,0.63],
        k=1
    )[0]


def strategy_random_choice_38_to_62(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.38,0.62],
        k=1
    )[0]


def strategy_random_choice_39_to_61(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.39,0.61],
        k=1
    )[0]


def strategy_random_choice_40_to_60(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.40,0.60],
        k=1
    )[0]


def strategy_random_choice_41_to_59(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.41,0.59],
        k=1
    )[0]


def strategy_random_choice_42_to_58(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.42,0.58],
        k=1
    )[0]


def strategy_random_choice_43_to_57(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.43,0.57],
        k=1
    )[0]


def strategy_random_choice_44_to_56(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.44,0.56],
        k=1
    )[0]


def strategy_random_choice_45_to_55(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.45,0.55],
        k=1
    )[0]


def strategy_random_choice_46_to_54(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.46,0.54],
        k=1
    )[0]


def strategy_random_choice_47_to_53(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.47,0.53],
        k=1
    )[0]


def strategy_random_choice_48_to_52(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.48,0.52],
        k=1
    )[0]


def strategy_random_choice_49_to_51(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.49,0.51],
        k=1
    )[0]


def strategy_random_choice_50_to_50(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.50,0.50],
        k=1
    )[0]


def strategy_random_choice_51_to_49(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.51,0.49],
        k=1
    )[0]


def strategy_random_choice_52_to_48(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.52,0.48],
        k=1
    )[0]


def strategy_random_choice_53_to_47(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.53,0.47],
        k=1
    )[0]


def strategy_random_choice_54_to_46(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.54,0.46],
        k=1
    )[0]


def strategy_random_choice_55_to_45(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.55,0.45],
        k=1
    )[0]


def strategy_random_choice_56_to_44(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.56,0.44],
        k=1
    )[0]


def strategy_random_choice_57_to_43(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.57,0.43],
        k=1
    )[0]


def strategy_random_choice_58_to_42(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.58,0.42],
        k=1
    )[0]


def strategy_random_choice_59_to_41(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.59,0.41],
        k=1
    )[0]


def strategy_random_choice_60_to_40(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.60,0.40],
        k=1
    )[0]


def strategy_random_choice_61_to_39(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.61,0.39],
        k=1
    )[0]


def strategy_random_choice_62_to_38(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.62,0.38],
        k=1
    )[0]


def strategy_random_choice_63_to_37(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.63,0.37],
        k=1
    )[0]


def strategy_random_choice_64_to_36(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.64,0.36],
        k=1
    )[0]


def strategy_random_choice_65_to_35(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.65,0.35],
        k=1
    )[0]


def strategy_random_choice_66_to_34(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.66,0.34],
        k=1
    )[0]


def strategy_random_choice_67_to_33(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.67,0.33],
        k=1
    )[0]


def strategy_random_choice_68_to_32(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.68,0.32],
        k=1
    )[0]


def strategy_random_choice_69_to_31(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.69,0.31],
        k=1
    )[0]


def strategy_random_choice_70_to_30(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.70,0.30],
        k=1
    )[0]


def strategy_random_choice_71_to_29(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.71,0.29],
        k=1
    )[0]


def strategy_random_choice_72_to_28(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.72,0.28],
        k=1
    )[0]


def strategy_random_choice_73_to_27(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.73,0.27],
        k=1
    )[0]


def strategy_random_choice_74_to_26(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.74,0.26],
        k=1
    )[0]


def strategy_random_choice_75_to_25(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.75,0.25],
        k=1
    )[0]


def strategy_random_choice_76_to_24(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.76,0.24],
        k=1
    )[0]


def strategy_random_choice_77_to_23(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.77,0.23],
        k=1
    )[0]


def strategy_random_choice_78_to_22(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.78,0.22],
        k=1
    )[0]


def strategy_random_choice_79_to_21(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.79,0.21],
        k=1
    )[0]


def strategy_random_choice_80_to_20(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.80,0.20],
        k=1
    )[0]


def strategy_random_choice_81_to_19(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.81,0.19],
        k=1
    )[0]


def strategy_random_choice_82_to_18(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.82,0.18],
        k=1
    )[0]


def strategy_random_choice_83_to_17(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.83,0.17],
        k=1
    )[0]


def strategy_random_choice_84_to_16(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.84,0.16],
        k=1
    )[0]


def strategy_random_choice_85_to_15(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.85,0.15],
        k=1
    )[0]


def strategy_random_choice_86_to_14(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.86,0.14],
        k=1
    )[0]


def strategy_random_choice_87_to_13(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.87,0.13],
        k=1
    )[0]


def strategy_random_choice_88_to_12(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.88,0.12],
        k=1
    )[0]


def strategy_random_choice_89_to_11(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.89,0.11],
        k=1
    )[0]


def strategy_random_choice_90_to_10(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.90,0.10],
        k=1
    )[0]


def strategy_random_choice_91_to_9(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.91,0.9],
        k=1
    )[0]


def strategy_random_choice_92_to_8(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.92,0.8],
        k=1
    )[0]


def strategy_random_choice_93_to_7(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.93,0.7],
        k=1
    )[0]


def strategy_random_choice_94_to_6(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.94,0.6],
        k=1
    )[0]


def strategy_random_choice_95_to_5(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.95,0.5],
        k=1
    )[0]


def strategy_random_choice_96_to_4(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.96,0.4],
        k=1
    )[0]


def strategy_random_choice_97_to_3(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.97,0.3],
        k=1
    )[0]


def strategy_random_choice_98_to_2(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.98,0.2],
        k=1
    )[0]


def strategy_random_choice_99_to_1(player, hist):
    if not player.is_human: return Choices.Shake
    return choices(
        population=[Choices.Zap, Choices.Shake],
        weights=[0.99,0.1],
        k=1
    )[0]


all_strategies = [
    strategy_always_shake, 
    strategy_random_choice, 
    strategy_always_zap, 
    strategy_random_choice_1_to_99,
strategy_random_choice_2_to_98,
strategy_random_choice_3_to_97,
strategy_random_choice_4_to_96,
strategy_random_choice_5_to_95,
strategy_random_choice_6_to_94,
strategy_random_choice_7_to_93,
strategy_random_choice_8_to_92,
strategy_random_choice_9_to_91,
strategy_random_choice_10_to_90,
strategy_random_choice_11_to_89,
strategy_random_choice_12_to_88,
strategy_random_choice_13_to_87,
strategy_random_choice_14_to_86,
strategy_random_choice_15_to_85,
strategy_random_choice_16_to_84,
strategy_random_choice_17_to_83,
strategy_random_choice_18_to_82,
strategy_random_choice_19_to_81,
strategy_random_choice_20_to_80,
strategy_random_choice_21_to_79,
strategy_random_choice_22_to_78,
strategy_random_choice_23_to_77,
strategy_random_choice_24_to_76,
strategy_random_choice_25_to_75,
strategy_random_choice_26_to_74,
strategy_random_choice_27_to_73,
strategy_random_choice_28_to_72,
strategy_random_choice_29_to_71,
strategy_random_choice_30_to_70,
strategy_random_choice_31_to_69,
strategy_random_choice_32_to_68,
strategy_random_choice_33_to_67,
strategy_random_choice_34_to_66,
strategy_random_choice_35_to_65,
strategy_random_choice_36_to_64,
strategy_random_choice_37_to_63,
strategy_random_choice_38_to_62,
strategy_random_choice_39_to_61,
strategy_random_choice_40_to_60,
strategy_random_choice_41_to_59,
strategy_random_choice_42_to_58,
strategy_random_choice_43_to_57,
strategy_random_choice_44_to_56,
strategy_random_choice_45_to_55,
strategy_random_choice_46_to_54,
strategy_random_choice_47_to_53,
strategy_random_choice_48_to_52,
strategy_random_choice_49_to_51,
strategy_random_choice_50_to_50,
strategy_random_choice_51_to_49,
strategy_random_choice_52_to_48,
strategy_random_choice_53_to_47,
strategy_random_choice_54_to_46,
strategy_random_choice_55_to_45,
strategy_random_choice_56_to_44,
strategy_random_choice_57_to_43,
strategy_random_choice_58_to_42,
strategy_random_choice_59_to_41,
strategy_random_choice_60_to_40,
strategy_random_choice_61_to_39,
strategy_random_choice_62_to_38,
strategy_random_choice_63_to_37,
strategy_random_choice_64_to_36,
strategy_random_choice_65_to_35,
strategy_random_choice_66_to_34,
strategy_random_choice_67_to_33,
strategy_random_choice_68_to_32,
strategy_random_choice_69_to_31,
strategy_random_choice_70_to_30,
strategy_random_choice_71_to_29,
strategy_random_choice_72_to_28,
strategy_random_choice_73_to_27,
strategy_random_choice_74_to_26,
strategy_random_choice_75_to_25,
strategy_random_choice_76_to_24,
strategy_random_choice_77_to_23,
strategy_random_choice_78_to_22,
strategy_random_choice_79_to_21,
strategy_random_choice_80_to_20,
strategy_random_choice_81_to_19,
strategy_random_choice_82_to_18,
strategy_random_choice_83_to_17,
strategy_random_choice_84_to_16,
strategy_random_choice_85_to_15,
strategy_random_choice_86_to_14,
strategy_random_choice_87_to_13,
strategy_random_choice_88_to_12,
strategy_random_choice_89_to_11,
strategy_random_choice_90_to_10,
strategy_random_choice_91_to_9,
strategy_random_choice_92_to_8,
strategy_random_choice_93_to_7,
strategy_random_choice_94_to_6,
strategy_random_choice_95_to_5,
strategy_random_choice_96_to_4,
strategy_random_choice_97_to_3,
strategy_random_choice_98_to_2,
strategy_random_choice_99_to_1,
]

# %%
basic_strats = [
    strategy_always_shake, 
    strategy_random_choice, 
    strategy_always_zap, 
]

# %%
zap_biased_strats = [
    strategy_random_choice_50_to_50,
strategy_random_choice_51_to_49,
strategy_random_choice_52_to_48,
strategy_random_choice_53_to_47,
strategy_random_choice_54_to_46,
strategy_random_choice_55_to_45,
strategy_random_choice_56_to_44,
strategy_random_choice_57_to_43,
strategy_random_choice_58_to_42,
strategy_random_choice_59_to_41,
strategy_random_choice_60_to_40,
strategy_random_choice_61_to_39,
strategy_random_choice_62_to_38,
strategy_random_choice_63_to_37,
strategy_random_choice_64_to_36,
strategy_random_choice_65_to_35,
strategy_random_choice_66_to_34,
strategy_random_choice_67_to_33,
strategy_random_choice_68_to_32,
strategy_random_choice_69_to_31,
strategy_random_choice_70_to_30,
strategy_random_choice_71_to_29,
strategy_random_choice_72_to_28,
strategy_random_choice_73_to_27,
strategy_random_choice_74_to_26,
strategy_random_choice_75_to_25,
strategy_random_choice_76_to_24,
strategy_random_choice_77_to_23,
strategy_random_choice_78_to_22,
strategy_random_choice_79_to_21,
strategy_random_choice_80_to_20,
strategy_random_choice_81_to_19,
strategy_random_choice_82_to_18,
strategy_random_choice_83_to_17,
strategy_random_choice_84_to_16,
strategy_random_choice_85_to_15,
strategy_random_choice_86_to_14,
strategy_random_choice_87_to_13,
strategy_random_choice_88_to_12,
strategy_random_choice_89_to_11,
strategy_random_choice_90_to_10,
strategy_random_choice_91_to_9,
strategy_random_choice_92_to_8,
strategy_random_choice_93_to_7,
strategy_random_choice_94_to_6,
strategy_random_choice_95_to_5,
strategy_random_choice_96_to_4,
strategy_random_choice_97_to_3,
strategy_random_choice_98_to_2,
strategy_random_choice_99_to_1,
]

# %%
class Player:
    def __init__(self, strategy=None):
        if strategy is None:
            strategy = strategy_random_choice
        self.strategy = strategy

    def draw(self, deck: list):
        self.card = choice(deck)
        deck.pop(deck.index(self.card))

    def play(self, hist):
        return self.strategy(self, hist)

    @property
    def is_human(self):
        return self.card == Card.Human


class Game:
    def __init__(self, players, deck, turn_limit=100):
        self.players = players
        self.deck = deck[:]
        self.turn_limit = turn_limit
        self.hist = []
        self.outcome = None

        for player in players:
            player.draw(deck)

    def add_turn(self):
        turn = []
        for player in self.players:
            turn.append(player.play(self.hist))
        self.hist.append(turn)

    def play(self):
        while len(self.hist) < self.turn_limit:
            self.add_turn()
            current_turn = self.hist[-1]
            if all([c == Choices.Shake for c in current_turn]):
                if all([p.is_human for p in self.players]):
                    return Outcome.BothWin
                else:
                    return Outcome.RobotWin
            # TODO: this only works for checking two player
            for (
                idx,
                c,
            ) in enumerate(current_turn):
                if c == Choices.Zap:
                    player_zapped = self.players[
                        not bool(idx)
                    ]  # only works for two player and kind of hacky
                    if player_zapped.is_human:
                        return Outcome.BothLose
                    else:
                        return Outcome.HumanWin
        return Outcome.Stalemate

    def apply_rules(self, turn):
        player_zero_play = turn[0]
        player_one_play = turn[1]

        if player_one_play == Choices.Shake and player_zero_play == Choices.Shake:
            if all([player.is_human for player in self.players]):
                return Outcome.BothWin
            else:
                return Outcome.RobotWin

    def get_outcome(self):
        if self.outcome == None:
            self.outcome = self.play()
        return self.outcome

    def player_index_is_winner(self, idx):
        player = self.players[idx]
        outcome = self.get_outcome()
        if outcome == Outcome.BothWin:
            return True
        elif outcome == Outcome.BothLose or outcome == Outcome.Stalemate:
            return False
        elif outcome == Outcome.HumanWin:
            return player.is_human
        elif outcome == Outcome.RobotWin:
            return not player.is_human


class Trial:
    def __init__(self, players, deck, turn_limit=100, n=100) -> None:
        self.d = {
            "player one wins": [],
            "player one loses": [],
            "player two wins": [],
            "player two loses": [],
        }
        self.players = players

        for _ in range(n):
            game = Game(players=players, deck=deck[:], turn_limit=turn_limit)
            self.d["player one wins"].append(int(game.player_index_is_winner(0)))
            self.d["player one loses"].append(int(not game.player_index_is_winner(0)))
            self.d["player two wins"].append(int(game.player_index_is_winner(1)))
            self.d["player two loses"].append(int(not game.player_index_is_winner(1)))

# %%
from pandas import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# this takes a ton of memory
def make_images(player_one, player_two, n):
    players = [player_one, player_two]
    deck = [Card.Human, Card.Robot, Card.Human]
    trial = Trial(players, deck[:], 100, n)
    df = pd.DataFrame(data=trial.d)
    player_one_strat_text = player_one.strategy.__name__.replace("_", " ")
    player_two_strat_text = player_two.strategy.__name__.replace("_", " ")
    green = "#55a868"
    red = "#c44e52"
    title = f"Player One {player_one_strat_text}\nPlayer Two {player_two_strat_text}"
    palette = sns.color_palette([green, red, green, red])


    trial_sns_plot = sns.catplot(
        aspect=1.5,
        kind='bar', 
        data=df,
        palette=palette 
    )
    trial_sns_plot.fig.subplots_adjust(top=0.9)

    trial_sns_plot.fig.suptitle(title)
    trial_sns_plot.set(ylim=(0, 1))
    trial_sns_plot.fig.savefig("images/"+title.replace(" ", "-").replace("\n","-")+".png")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/brev/workspace/jupyter/work/ayar.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bjupyter-nmj8/home/brev/workspace/jupyter/work/ayar.ipynb#ch0000006vscode-remote?line=0'>1</a> from pandas import pandas as pd
#       <a href='vscode-notebook-cell://ssh-remote%2Bjupyter-nmj8/home/brev/workspace/jupyter/work/ayar.ipynb#ch0000006vscode-remote?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell://ssh-remote%2Bjupyter-nmj8/home/brev/workspace/jupyter/work/ayar.ipynb#ch0000006vscode-remote?line=2'>3</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
def get_trial(player_one, player_two, n):
    players = [player_one, player_two]
    deck = [Card.Human, Card.Robot, Card.Human]
    trial = Trial(players, deck[:], 100, n)
    return trial

# %%
def apply_fn_to_all_strategies(fn, all_strategies, *args, **kwargs):
    dupes = set()
    for x in all_strategies:
        for y in all_strategies:
            if x.__name__ + y.__name__ in dupes:
                continue
            else:
                yield fn(Player(y),Player(x), *args, **kwargs)
                dupes.add(y.__name__ + x.__name__)
                dupes.add(x.__name__ + y.__name__)

# %%
list(apply_fn_to_all_strategies(make_images, basic_strats, 100))
# Out:
# [None, None, None, None, None, None]

# %%
from collections import defaultdict
def strategy_win_loss_table(trials):
    acc = defaultdict(bool)
    for trial in trials:
        player_one = trial.players[0]
        player_two = trial.players[1]
        player_one_strat_text = player_one.strategy.__name__.replace("_", " ")
        player_one_wins = sum(trial.d["player one wins"])
        player_one_losses = sum(trial.d["player one loses"])
        player_two_strat_text = player_two.strategy.__name__.replace("_", " ")
        player_two_wins = sum(trial.d["player two wins"])
        player_two_losses = sum(trial.d["player two loses"])
        if acc[player_one_strat_text]:
            acc[player_one_strat_text]["wins"] += player_one_wins
            acc[player_one_strat_text]["losses"] +=  player_one_losses
        else:
            acc[player_one_strat_text] = {
                "wins": player_one_wins,
                "losses": player_one_losses
            }
        if acc[player_two_strat_text]:
            acc[player_two_strat_text]["wins"] += player_two_wins
            acc[player_two_strat_text]["losses"] += player_two_losses
        else:
            acc[player_two_strat_text] = {
                "wins": player_two_wins,
                "losses": player_two_losses
            }
    return acc

# %%
trials = apply_fn_to_all_strategies(get_trial, all_strategies, 100)
table = strategy_win_loss_table(trials)
for l in reversed(sorted(table, key=lambda k: table[k]["wins"])):
    print(table[l]["wins"], table[l]["losses"], l)
# Out:
# 5096 5204 strategy always zap
# 5016 5284 strategy random choice 88 to 12
# 5008 5292 strategy random choice 89 to 11
# 5005 5295 strategy random choice 99 to 1
# 4995 5305 strategy random choice 87 to 13
# 4942 5358 strategy random choice 98 to 2
# 4895 5405 strategy random choice 86 to 14
# 4892 5408 strategy random choice 85 to 15
# 4876 5424 strategy random choice 90 to 10
# 4872 5428 strategy random choice 82 to 18
# 4841 5459 strategy random choice 78 to 22
# 4828 5472 strategy random choice 83 to 17
# 4821 5479 strategy random choice 81 to 19
# 4806 5494 strategy random choice 80 to 20
# 4792 5508 strategy random choice 77 to 23
# 4775 5525 strategy random choice 84 to 16
# 4767 5533 strategy random choice 76 to 24
# 4687 5613 strategy random choice 96 to 4
# 4663 5637 strategy random choice 75 to 25
# 4661 5639 strategy random choice 97 to 3
# 4658 5642 strategy random choice 79 to 21
# 4634 5666 strategy random choice 73 to 27
# 4626 5674 strategy random choice 69 to 31
# 4623 5677 strategy random choice 66 to 34
# 4621 5679 strategy random choice 72 to 28
# 4620 5680 strategy random choice 65 to 35
# 4619 5681 strategy random choice 74 to 26
# 4617 5683 strategy random choice 64 to 36
# 4585 5715 strategy random choice 68 to 32
# 4570 5730 strategy random choice 95 to 5
# 4513 5787 strategy random choice 70 to 30
# 4507 5793 strategy random choice 71 to 29
# 4498 5802 strategy random choice 94 to 6
# 4490 5810 strategy random choice 67 to 33
# 4488 5812 strategy random choice 63 to 37
# 4483 5817 strategy random choice 61 to 39
# 4475 5825 strategy random choice 57 to 43
# 4460 5840 strategy random choice 60 to 40
# 4458 5842 strategy random choice 62 to 38
# 4439 5861 strategy random choice 56 to 44
# 4436 5864 strategy random choice 59 to 41
# 4409 5891 strategy random choice 58 to 42
# 4385 5915 strategy random choice 55 to 45
# 4356 5944 strategy random choice 54 to 46
# 4352 5948 strategy random choice 51 to 49
# 4347 5953 strategy random choice
# 4332 5968 strategy random choice 50 to 50
# 4330 5970 strategy random choice 53 to 47
# 4326 5974 strategy random choice 93 to 7
# 4325 5975 strategy random choice 52 to 48
# 4309 5991 strategy random choice 91 to 9
# 4296 6004 strategy random choice 49 to 51
# 4273 6027 strategy random choice 92 to 8
# 4238 6062 strategy random choice 44 to 56
# 4236 6064 strategy random choice 9 to 91
# 4231 6069 strategy random choice 46 to 54
# 4228 6072 strategy random choice 48 to 52
# 4222 6078 strategy random choice 45 to 55
# 4194 6106 strategy random choice 43 to 57
# 4181 6119 strategy random choice 7 to 93
# 4171 6129 strategy random choice 42 to 58
# 4164 6136 strategy random choice 36 to 64
# 4150 6150 strategy random choice 41 to 59
# 4149 6151 strategy random choice 8 to 92
# 4146 6154 strategy random choice 47 to 53
# 4128 6172 strategy random choice 38 to 62
# 4119 6181 strategy random choice 40 to 60
# 4102 6198 strategy random choice 6 to 94
# 4082 6218 strategy random choice 37 to 63
# 4070 6230 strategy random choice 39 to 61
# 4058 6242 strategy random choice 5 to 95
# 4047 6253 strategy random choice 32 to 68
# 4025 6275 strategy random choice 34 to 66
# 4010 6290 strategy random choice 33 to 67
# 3999 6301 strategy random choice 4 to 96
# 3986 6314 strategy random choice 35 to 65
# 3985 6315 strategy random choice 29 to 71
# 3953 6347 strategy random choice 27 to 73
# 3942 6358 strategy random choice 30 to 70
# 3938 6362 strategy random choice 26 to 74
# 3888 6412 strategy random choice 23 to 77
# 3877 6423 strategy random choice 31 to 69
# 3873 6427 strategy random choice 28 to 72
# 3870 6430 strategy random choice 22 to 78
# 3868 6432 strategy random choice 25 to 75
# 3849 6451 strategy random choice 24 to 76
# 3836 6464 strategy random choice 19 to 81
# 3833 6467 strategy random choice 3 to 97
# 3832 6468 strategy random choice 20 to 80
# 3814 6486 strategy random choice 21 to 79
# 3754 6546 strategy random choice 18 to 82
# 3750 6550 strategy random choice 2 to 98
# 3725 6575 strategy random choice 16 to 84
# 3715 6585 strategy random choice 12 to 88
# 3712 6588 strategy random choice 13 to 87
# 3675 6625 strategy random choice 17 to 83
# 3674 6626 strategy random choice 15 to 85
# 3673 6627 strategy random choice 10 to 90
# 3656 6644 strategy random choice 14 to 86
# 3603 6697 strategy random choice 1 to 99
# 3584 6716 strategy random choice 11 to 89
# 3487 6813 strategy always shake

# %%
biased_trials = apply_fn_to_all_strategies(get_trial, zap_biased_strats, 100)
biased_table = strategy_win_loss_table(biased_trials)
for l in reversed(sorted(biased_table, key=lambda k: biased_table[k]["wins"])):
    print(biased_table[l]["wins"], biased_table[l]["losses"], l)
# Out:
# 2148 2952 strategy random choice 89 to 11
# 2085 3015 strategy random choice 87 to 13
# 2077 3023 strategy random choice 86 to 14
# 2064 3036 strategy random choice 99 to 1
# 2064 3036 strategy random choice 88 to 12
# 2052 3048 strategy random choice 90 to 10
# 2041 3059 strategy random choice 84 to 16
# 2028 3072 strategy random choice 82 to 18
# 2016 3084 strategy random choice 83 to 17
# 1990 3110 strategy random choice 98 to 2
# 1989 3111 strategy random choice 75 to 25
# 1985 3115 strategy random choice 85 to 15
# 1963 3137 strategy random choice 81 to 19
# 1957 3143 strategy random choice 97 to 3
# 1957 3143 strategy random choice 78 to 22
# 1956 3144 strategy random choice 79 to 21
# 1954 3146 strategy random choice 77 to 23
# 1942 3158 strategy random choice 80 to 20
# 1937 3163 strategy random choice 73 to 27
# 1925 3175 strategy random choice 72 to 28
# 1910 3190 strategy random choice 76 to 24
# 1896 3204 strategy random choice 74 to 26
# 1882 3218 strategy random choice 71 to 29
# 1880 3220 strategy random choice 96 to 4
# 1854 3246 strategy random choice 67 to 33
# 1845 3255 strategy random choice 70 to 30
# 1842 3258 strategy random choice 68 to 32
# 1834 3266 strategy random choice 69 to 31
# 1811 3289 strategy random choice 60 to 40
# 1807 3293 strategy random choice 62 to 38
# 1806 3294 strategy random choice 65 to 35
# 1793 3307 strategy random choice 66 to 34
# 1790 3310 strategy random choice 61 to 39
# 1782 3318 strategy random choice 63 to 37
# 1770 3330 strategy random choice 95 to 5
# 1757 3343 strategy random choice 64 to 36
# 1746 3354 strategy random choice 94 to 6
# 1739 3361 strategy random choice 58 to 42
# 1710 3390 strategy random choice 59 to 41
# 1710 3390 strategy random choice 52 to 48
# 1687 3413 strategy random choice 92 to 8
# 1686 3414 strategy random choice 93 to 7
# 1675 3425 strategy random choice 56 to 44
# 1673 3427 strategy random choice 91 to 9
# 1664 3436 strategy random choice 51 to 49
# 1654 3446 strategy random choice 55 to 45
# 1648 3452 strategy random choice 54 to 46
# 1642 3458 strategy random choice 57 to 43
# 1641 3459 strategy random choice 50 to 50
# 1615 3485 strategy random choice 53 to 47
